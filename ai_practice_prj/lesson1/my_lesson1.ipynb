# %% [markdown]
# # Thuc hanh tri tue nhan tao Buoi 1
# ## Noi dung thuc hanh

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# ### Chay tap tin python

# %%
# !python ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %% [markdown]
# ### Tinh toan don gian

# %%
# %run ex1_cale.py
# Out:
# Calculator Basic
# Moi ban nhap so a:  2
# Moi ban nhap so b:  4
# c = 2 + 4 = 6

# %% [markdown]
# ### Tinh toan khoa hoc

# %%
# %run ex2_scientufic1.py
# Out:
# + x: len=50, [0.00, 0.98]: 10 samples [[0.69155664 0.65703004 0.31185994 0.33613125 0.75505132 0.33510241
#  0.51751726 0.1740547  0.66729533 0.18798096]]
# + y: len=50, [0.01, 0.99]: 10 samples [[0.08589248 0.40609102 0.30040228 0.73268304 0.44421306 0.41107897
#  0.35975637 0.53022306 0.45605718 0.148927  ]]
# + colors: len=50, [0.08, 0.99]: 10 samples [[0.7749207  0.4371471  0.90002304 0.35463799 0.8906931  0.36504296
#  0.560592   0.43421141 0.30241238 0.67514236]]
# + area: len=50, [0.00, 678.54]: 10 samples [[312.53997673  53.98340678 246.57597831 110.00616263 436.63851145
#  275.45193544 136.82128269 304.48049602   5.58392762  32.74934615]]

# %% [markdown]
# ### Tinh chu vi va dien tich hinh tron

# %%
# %run ex3_circle.py
# Out:
# Nhap ban kinh r:  2
# Ban kinh: 2.0
# Chu vi hinh tron: 12.566370614359172
# Dien tich hinh tron: 12.566370614359172

# %% [markdown]
# # Ket Thuc
